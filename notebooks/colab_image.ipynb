# %% [markdown]
# # Real vs Fake Face Detection - Dataset Quickstart
#
# Complete the steps in this notebook to get setup with the dataset for RvF. To get started, run the following cell for setup. This will prompt a dialog for you to connect Google Colab to your Google Drive - make sure to accept this (so you can access files stored on your Google Drive).
#
#
# You should make sure you are able to run this notebook succesfully before we get started with model development!
#
# 🚨 **CRITICAL** 🚨: Before you make any changes to this notebook, make a copy of this notebook to your Google Drive! On the top left of your screen, click "File > Save as copy to Drive" or click "Copy to Drive".
#
# ![image.png](data:image/png;base64,...)

# %%
# !sudo apt-get install tree -y
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# ## Step 1 - Cloning the Repository
#
# We will use `git clone` to clone our repository to the local Google Colab instance.
#
# Click [here](https://github.com/MichiganDataScienceTeam/W24-RvF.git) you want to browse the files on our repository via GitHub.

# %%
# !git clone https://github.com/MichiganDataScienceTeam/W24-RvF.git

# %% [markdown]
# You can confirm that the clone was successful by running the cell below. You should see the following output:
#
# ```bash
# W24-RvF
# ├── data
# │   └── download.sh
# ├── media
# │   └── kaggle_instructions.png
# ├── README.md
# └── requirements.txt
# ```

# %%
# !tree W24-RvF

# %% [markdown]
# # Step 2 - Getting a Kaggle API Key

# %% [markdown]
# This step doesn't involve running any code on Colab. Instead, you will go to [**Kaggle**](kaggle.com) and get an API Key.
#
# Kaggle is a platform for data scientists to compete against each other and to collect shared resources (like guides, tutorials, and datasets). We will use Kaggle to download the data for this project, but it is a great data science resource regardless!
#
# 1. Create a Kaggle account if you don't have one already
# 2. When logged in, click on your profile icon in the top right. In the side menu that pops up, select "Settings"
# ![Kaggle API Token Creation Screenshot](https://github.com/MichiganDataScienceTeam/W24-RvF/blob/main/media/kaggle_settings.gif?raw=true)
#
# 3. You should see a page similar to the screenshot below. Click on the "Create New Token" button.
# ![Kaggle API Token Creation Screenshot](https://github.com/MichiganDataScienceTeam/W24-RvF/blob/main/media/kaggle_instructions.png?raw=true)
#
# 4. Download `kaggle.json` and upload it to your Google Drive. You can upload this wherever your prefer. **Replace the default path with the path the folder on your Google Drive containing this file in the cell below**.

# %%
# replace the default path value below with the path to the folder containing your `kaggle.json` file!

# %env KAGGLE_KEY_FOLDER=MDST/RvF

# %% [markdown]
# ## Step 3 - Install Required Python Packages
#
# We can do this easily by running the cell below. This cell can take a couple of minutes to run (~5 minutes).
#
# You may also have to restart the Colab Session when done (just be sure to click the button - you won't lose any files in this process!)

# %%
# !pip install -r W24-RvF/requirements.txt

# %% [markdown]
# ## Step 4 - Dataset Download
#
# Run the cell below, and if everything runs successfully, you've setup everything correctly!
#
# You may see a warning regarding your environment like below. You can ignore this warning message when running the setup on Google Colab.
#
# ```
# WARNING: Your Python virtual environment should be enabled while running this script!
# ```

# %%
# !export KAGGLE_CONFIG_DIR=/content/drive/MyDrive/$KAGGLE_KEY_FOLDER &&cd W24-RvF && ./data/download.sh

# %% [markdown]
# If everything ran successfully, you should see a directory structure under the `W24-RvF` folder that looks like the following:
#
# ```bash
# W24-RvF
# ├── README.md
# ├── data
# │   ├── download.sh
# │   └── rvf140k
# │       └── ... // all the dataset content
# ├── media
# │   └── ... // screenshots
# ├── notebooks
# │   └── ... // notebooks that we will use throughout the project
# └── requirements.txt
# ```
